# %% [markdown]
# <a href="https://colab.research.google.com/github/mona-jha/Machine-Learning-II/blob/main/problem_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><b>Assignmen-1(ML2)<b> <br>
#
#
# <h2> Name : Mona Kumari <br>
# Roll No. :<b> CS2311</b>

# %% [markdown]
# ![4.1.png](data:image/png;base64,...)

# %% [markdown]
# ![4.1-solution.png](data:image/png;base64,...)
